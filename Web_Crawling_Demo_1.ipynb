# %%
# 4 Major Python Libraries for Web Crawling
# (1) Pandas - Parsing HTML Tables
# (2) Request - Parsing HTML Codes
# (3) BeautifulSoup - Analyzing HTML Codes
# (4) Selenium - Automating Browser Activities

# All labs in these lessons are meant for demonstrating web crawling techniques only.
# Please Google and try to understand in details the ethics and best practice for web crawling.
# e.g. https://sunscrapers.com/blog/web-crawling-scraping-best-practices/

# %%
# Install all these libraries to your environment
import pandas as pd

# %%
# Read CSV file online
nikkei_url = "https://query1.finance.yahoo.com/v7/finance/download/%5EN225?period1=-157420800&period2=1636243200&interval=1d&events=history&includeAdjustedClose=true"
nikkei_df = pd.read_csv(nikkei_url)
nikkei_df
# Out:
#              Date          Open          High           Low         Close  \
# 0      1965-01-05   1257.719971   1257.719971   1257.719971   1257.719971
# 1      1965-01-06   1263.989990   1263.989990   1263.989990   1263.989990
# 2      1965-01-07   1274.270020   1274.270020   1274.270020   1274.270020
# 3      1965-01-08   1286.430054   1286.430054   1286.430054   1286.430054
# 4      1965-01-11           NaN           NaN           NaN           NaN
# ...           ...           ...           ...           ...           ...
# 14600  2021-10-29  28819.160156  29000.650391  28475.060547  28892.689453
# 14601  2021-11-01  29330.679688  29666.830078  29267.630859  29647.080078
# 14602  2021-11-02  29462.400391  29599.570313  29457.179688  29520.900391
# 14603  2021-11-04  29859.740234  29880.810547  29718.779297  29794.369141
# 14604  2021-11-05  29840.730469  29840.730469  29504.070313  29611.570313
#
#           Adj Close       Volume
# 0       1257.719971          0.0
# 1       1263.989990          0.0
# 2       1274.270020          0.0
# 3       1286.430054          0.0
# 4               NaN          NaN
# ...             ...          ...
# 14600  28892.689453  104500000.0
# 14601  29647.080078   76700000.0
# 14602  29520.900391   71100000.0
# 14603  29794.369141   90400000.0
# 14604  29611.570313   73500000.0
#
# [14605 rows x 7 columns]

# %%
# Read tables online, returning array of tables
news_url = "https://www.skysports.com/champions-league-table"
news_df = pd.read_html(news_url)
news_df
# Out:
# [   #               Team  Pl  W  D  L   F   A  GD  Pts  Last 6
#  0  1      Bayern Munich   6  5  1  0  12   6   6   16     NaN
#  1  2      FC Copenhagen   6  2  2  2   8   8   0    8     NaN
#  2  3        Galatasaray   6  1  2  3  10  13  -3    5     NaN
#  3  4  Manchester United   6  1  1  4  12  15  -3    4     NaN,
#     #           Team  Pl  W  D  L   F   A  GD  Pts  Last 6
#  0  1        Arsenal   6  4  1  1  16   4  12   13     NaN
#  1  2  PSV Eindhoven   6  2  3  1   8  10  -2    9     NaN
#  2  3        RC Lens   6  2  2  2   6  11  -5    8     NaN
#  3  4        Sevilla   6  0  2  4   7  12  -5    2     NaN,
#     #                Team  Pl  W  D  L   F   A  GD  Pts  Last 6
#  0  1         Real Madrid   6  6  0  0  16   7   9   18     NaN
#  1  2              Napoli   6  3  1  2  10   9   1   10     NaN
#  2  3               Braga   6  1  1  4   6  12  -6    4     NaN
#  3  4  1. FC Union Berlin   6  0  2  4   6  10  -4    2     NaN,
#     #               Team  Pl  W  D  L  F   A  GD  Pts  Last 6
#  0  1      Real Sociedad   6  3  3  0  7   2   5   12     NaN
#  1  2        Inter Milan   6  3  3  0  8   5   3   12     NaN
#  2  3            Benfica   6  1  1  4  7  11  -4    4     NaN
#  3  4  Red Bull Salzburg   6  1  1  4  4   8  -4    4     NaN,
#     #             Team  Pl  W  D  L   F   A  GD  Pts  Last 6
#  0  1  Atletico Madrid   6  4  2  0  17   6  11   14     NaN
#  1  2            Lazio   6  3  1  2   7   7   0   10     NaN
#  2  3        Feyenoord   6  2  0  4   9  10  -1    6     NaN
#  3  4           Celtic   6  1  1  4   5  15 -10    4     NaN,
#     #                 Team  Pl  W  D  L  F  A  GD  Pts  Last 6
#  0  1    Borussia Dortmund   6  3  2  1  7  4   3   11     NaN
#  1  2  Paris Saint-Germain   6  2  2  2  9  8   1    8     NaN
#  2  3             AC Milan   6  2  2  2  5  8  -3    8     NaN
#  3  4     Newcastle United   6  1  2  3  6  7  -1    5     NaN,
#     #                 Team  Pl  W  D  L   F   A  GD  Pts  Last 6
#  0  1      Manchester City   6  6  0  0  18   7  11   18     NaN
#  1  2           RB Leipzig   6  4  0  2  13  10   3   12     NaN
#  2  3  BSC Young Boys Bern   6  1  1  4   7  13  -6    4     NaN
#  3  4        Crvena Zvezda   6  0  1  5   7  15  -8    1     NaN,
#     #              Team  Pl  W  D  L   F   A  GD  Pts  Last 6
#  0  1         Barcelona   6  4  0  2  12   6   6   12     NaN
#  1  2          FC Porto   6  4  0  2  15   8   7   12     NaN
#  2  3  Shakhtar Donetsk   6  3  0  3  10  12  -2    9     NaN
#  3  4           Antwerp   6  1  0  5   6  17 -11    3     NaN]

# %%
len(news_df)
# Out:
# 8

# %%
news_df[0]
# Out:
#    #               Team  Pl  W  D  L   F   A  GD  Pts  Last 6
# 0  1      Bayern Munich   6  5  1  0  12   6   6   16     NaN
# 1  2      FC Copenhagen   6  2  2  2   8   8   0    8     NaN
# 2  3        Galatasaray   6  1  2  3  10  13  -3    5     NaN
# 3  4  Manchester United   6  1  1  4  12  15  -3    4     NaN

# %% [markdown]
# <h2>Technique - Data Cleansing</h2>

# %%
# Removing unnecessary columns - method 1
news_df_0_a = news_df[0].drop(["#", "Last 6"], axis=1)
news_df_0_a
# Out:
#                 Team  Pl  W  D  L   F   A  GD  Pts
# 0      Bayern Munich   6  5  1  0  12   6   6   16
# 1      FC Copenhagen   6  2  2  2   8   8   0    8
# 2        Galatasaray   6  1  2  3  10  13  -3    5
# 3  Manchester United   6  1  1  4  12  15  -3    4

# %%
# Removing unnecessary columns - method 2
news_df_0_b = news_df[0][["Team", "Pl", "W", "D", "L", "F", "A", "GD", "Pts"]]
news_df_0_b
# Out:
#                 Team  Pl  W  D  L   F   A  GD  Pts
# 0      Bayern Munich   6  5  1  0  12   6   6   16
# 1      FC Copenhagen   6  2  2  2   8   8   0    8
# 2        Galatasaray   6  1  2  3  10  13  -3    5
# 3  Manchester United   6  1  1  4  12  15  -3    4
